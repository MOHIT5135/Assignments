# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\mohit\Desktop\Data Analysis\ds_salaries.csv")

# %%
data.head(5)
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='str')

# %%
data["salary_currency"].unique()
# Out:
# <StringArray>
# ['EUR', 'USD', 'GBP', 'HUF', 'INR', 'JPY', 'CNY', 'MXN', 'CAD', 'DKK', 'PLN',
#  'SGD', 'CLP', 'BRL', 'TRY', 'AUD', 'CHF']
# Length: 17, dtype: str

# %%
data["job_title"].unique()
# Out:
# <StringArray>
# [                          'Data Scientist',
#                'Machine Learning Scientist',
#                         'Big Data Engineer',
#                      'Product Data Analyst',
#                 'Machine Learning Engineer',
#                              'Data Analyst',
#                       'Lead Data Scientist',
#                     'Business Data Analyst',
#                        'Lead Data Engineer',
#                         'Lead Data Analyst',
#                             'Data Engineer',
#                   'Data Science Consultant',
#                           'BI Data Analyst',
#                  'Director of Data Science',
#                        'Research Scientist',
#                  'Machine Learning Manager',
#                  'Data Engineering Manager',
#  'Machine Learning Infrastructure Engineer',
#                               'ML Engineer',
#                              'AI Scientist',
# ...

# %%
sns.countplot(data, x="experience_level")
plt.show()

# %%
sns.countplot(data, x="remote_ratio")
plt.show()

# %%
sns.countplot(data, x="company_size")
plt.show()

# %%
sns.countplot(data, x="remote_ratio", hue = "company_size")
plt.grid(axis = 'y')
plt.show()

# %%
sns.countplot(data, x="company_size", hue = "experience_level")
plt.grid(axis='y')
plt.show()
